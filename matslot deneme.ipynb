# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('googleplaystore.csv',)
df['Reviews']
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
# 5           167
# 6           178
# 7         36815
# 8         13791
# 9           121
# 10        13880
# 11         8788
# 12        44829
# 13         4326
# 14         1518
# 15           55
# 16         3632
# 17           27
# 18       194216
# 19       224399
# 20          450
# 21          654
# 22         7699
# 23           61
# 24          118
# 25          192
# 26        20260
# 27          203
# 28          136
# 29          223
#           ...
# 10811         4
# 10812        80
# 10813        20
# 10814       785
# 10815      5775
# 10816         2
# 10817       885
# 10818        96
# 10819        52
# 10820        22
# 10821         6
# 10822         0
# 10823         1
# 10824        67
# 10825         7
# 10826     88486
# 10827       117
# 10828       291
# 10829       603
# 10830       881
# 10831        38
# 10832      1195
# 10833        44
# 10834         7
# ...

# %%
df.loc[lambda df:(df['Rating']<2)&(df['Rating']>1) ,:]
# Out:
#                                   App             Category  Rating Reviews  \
# 518     Just She - Top Lesbian Dating               DATING     1.9     953
# 554     Just She - Top Lesbian Dating               DATING     1.9     953
# 663     Just She - Top Lesbian Dating               DATING     1.9     954
# 4006                          C by GE            LIFESTYLE     1.7     686
# 4161                      G-Playlists                TOOLS     1.8      53
# 4522             Q-Tech Companion App       FOOD_AND_DRINK     1.8      17
# 4726                        W Box VMS        VIDEO_PLAYERS     1.9     105
# 4904   Smart-AC Universal Remote Free               FAMILY     1.8    3270
# 4905          AC REMOTE UNIVERSAL-PRO               FAMILY     1.6     402
# 4906                 Kenmore Smart AC            LIFESTYLE     1.9      71
# 4925         A/C REFRIGERANT CAPACITY             BUSINESS     1.7      84
# ...

# %%
df.loc[lambda df:(df['Rating']<2)&(df['Rating']>1) ,:].groupby(by='Rating').mean()['Reviews']
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-4-712bddb54341> in <module>
# ----> 1 df.loc[lambda df:(df['Rating']<2)&(df['Rating']>1) ,:].groupby(by='Rating').mean()['Reviews']
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1304         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1305         try:
# -> 1306             return self._cython_agg_general('mean', **kwargs)
#    1307         except GroupByError:
#    1308             raise
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    3970                             min_count=-1):
#    3971         new_items, new_blocks = self._cython_agg_blocks(
# -> 3972             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
# ...

# %%
df.loc[lambda df:(df['Rating']<2)&(df['Rating']>1) ,:].mean()['Reviews']

# %%
df.groupby(by='Rating').sum()['Reviews']

# %%
df.dtypes
df['Reviews'][i]

# %%
df['Reviews'][0]
# Out:
# '159'

# %%
float(df['Reviews'][0])
# Out:
# 159.0

# %%
len(df['Reviews'])
# Out:
# 10841

# %%
for i in range(3):
    df['Reviews'][i]=float(df['Reviews'][i])
    print(type(df['Reviews'][i]))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.loc[lambda df:(df['Rating']<2)&(df['Rating']>1) ,:].groupby(by='Rating').mean()['Reviews',dtype=float]
# Out:
#   File "<ipython-input-17-3600cd9242c4>", line 1
#     df.loc[lambda df:(df['Rating']<2)&(df['Rating']>1) ,:].groupby(by='Rating').mean()['Reviews',dtype=float]
#                                                                                                       ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('googleplaystore.csv',dtype={'Reviews': np.float64})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array from dtype('O') to dtype('float64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b3cbc3aeeb34> in <module>
# ----> 1 df = pd.read_csv('googleplaystore.csv',dtype={'Reviews': np.float64})
#
# ...

# %%
df['Reviews']=df['Reviews'].astype(np.float64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-a48fb11fcad7> in <module>
# ----> 1 df['Reviews']=df['Reviews'].astype(np.float64)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...

# %%
df['Reviews'].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna)
#     506         else:
# --> 507             result = getattr(values, meth)(axis)
#     508
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial)
#      27           initial=_NoValue):
# ---> 28     return umr_maximum(a, axis, None, out, keepdims, initial)
#      29
#
# TypeError: '>=' not supported between instances of 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df['Reviews']
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
# 5           167
# 6           178
# 7         36815
# 8         13791
# 9           121
# 10        13880
# 11         8788
# 12        44829
# 13         4326
# 14         1518
# 15           55
# 16         3632
# 17           27
# 18       194216
# 19       224399
# 20          450
# 21          654
# 22         7699
# 23           61
# 24          118
# 25          192
# 26        20260
# 27          203
# 28          136
# 29          223
#           ...
# 10811         4
# 10812        80
# 10813        20
# 10814       785
# 10815      5775
# 10816         2
# 10817       885
# 10818        96
# 10819        52
# 10820        22
# 10821         6
# 10822         0
# 10823         1
# 10824        67
# 10825         7
# 10826     88486
# 10827       117
# 10828       291
# 10829       603
# 10830       881
# 10831        38
# 10832      1195
# 10833        44
# 10834         7
# ...

# %%
df.loc[lambda df:(df['Rating']<2)&(df['Rating']>1) ,:]['Reviews'].astype(np.float64).mean()
# Out:
# 261.325

# %%
df.loc[lambda df:(df['Rating']<5)&(df['Rating']>4.5) ,:]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 34                                       I Creative Idea       ART_AND_DESIGN
# 36        UNICORN - Color By Number & Pixel Art Coloring       ART_AND_DESIGN
# ...
